# %%
import cv2 as cv
import numpy as np

# %%
video_path = ('/Users/agerasymchuk/private_repo/cv_claude_course/cv_course/videos/color.mp4')
output_path = 'grayscale_video.mp4'


cap =
